# %%
elevation_gain = 500
elevation_loss = -500

result = abs(elevation_loss) + elevation_gain
label = "total elevation change: "

print(label, result) # method 1
print(f"{label} {result}") # method 2
# Out:
# total elevation change:  1000
# total elevation change:  1000

# %% [markdown]
# Alex is interested in knowing the absolute difference in his day-to-day step counts. Create two variables, todays_steps = 11240 and yesterdays_steps = 4290, and compute the absolute difference.

# %%
todays_steps = 11240
yesterdays_steps = 14290
absolute_difference = abs(todays_steps - yesterdays_steps)
print(f"The absolute difference is {absolute_difference} steps")
# Out:
# The absolute difference is 3050 steps

# %% [markdown]
# Beyond being interested in the absolute difference from yesterday to today, Alex is also interested in identifying the most steps he took in the last seven days. Given that in the last seven days Alex took 9820, 15400, 12980, 10090, 13820, 11240, and 14290 steps, use a built-in function to identify the most steps Alex took.

# %%
last_7_days_steps = [9820, 15400, 12980, 10090, 13820, 11240, 14290]
print(max(last_7_days_steps))
# Out:
# 15400

# %% [markdown]
# In the spirit of analyzing extremes, Alex would like you to identify the fastest time in his last five 100 meter dash attempts: 14.89, 14.02, 15.67, 13.91, 13.87. Use a built-in function to do this.

# %%
fastest_time = [14.89, 14.02, 15.67, 13.91, 13.87]
print(min(fastest_time))
# Out:
# 13.87

# %% [markdown]
# # STRING FUNCTIONS

# %%
str = "i am a coder."

# %% [markdown]
# Returns true if string ends with substr.

# %%
str.endswith("er.")
# Out:
# True

# %% [markdown]
# Capitalizes 1st char.

# %%
str.capitalize()
# Out:
# 'I am a coder.'

# %% [markdown]
# Replaces all occurances of old with new.

# %%
str.replace("coder", "programmer")
# Out:
# 'i am a programmer.'

# %% [markdown]
# Returns 1st index of 1st occurance.

# %%
str.find("c")
# Out:
# 7

# %% [markdown]
# Counts the occurance of substr in string.

# %%
str.count("am")
# Out:
# 1

# %%
str.upper()
# Out:
# 'I AM A CODER.'

# %%
str.lower()
# Out:
# 'i am a coder.'

# %%
str.title()
# Out:
# 'I Am A Coder.'

# %%
len(str)
# Out:
# 13

# %% [markdown]
# WAP to input user's first name & print its length.

# %%
name = input("Enter your name: ")
print("length of your name is", len(name))
# Out:
# length of your name is 4

# %% [markdown]
# WAP to find the occurance of 'S' in a string.

# %%
print(name.count("S"))
# Out:
# 1

# %%
x = float(input("what is x?"))
y = float(input("what is y?"))
z = round((x + y))

print(f"{z:,}")   # put a comma to separate thousands
# Out:
# 10,584

# %%
# Method 1: using round() function
x = float(input("what is x?"))
y = float(input("what is y?"))
z = round(x / y, 2)

print(z)
# Out:
# 1.43

# %%
# Method 2: using f-string formatting
x = float(input("what is x?"))
y = float(input("what is y?"))
z = x / y

print(f"{z:.2f}")
# Out:
# 4.26

# %% [markdown]
# To add and display an image in Python, you can use different libraries depending on your needs:

# %% [markdown]
# ## 1. Using Python (Recommended for Local Images) in VSCode jupyter notebook
# ```python
# from IPython.display import display, Image
#
# display(Image(filename="C:/Users/Yahya/Desktop/My folder/Programming/Python/DataSciencePython/while loops.png"))

# %% [markdown]
# ## 2. Using Matplotlib (For Visualization)
# ```python
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
#
# img = mpimg.imread("image.jpg")  # Load the image
# plt.imshow(img)  # Display the image
# plt.axis("off")  # Hide axes
# plt.show()

# %% [markdown]
# ## 3. Using OpenCV (For Image Processing)
# ```python
# import cv2
#
# img = cv2.imread("image.jpg")  # Load the image
# cv2.imshow("Image", img)  # Display the image
# cv2.waitKey(0)  # Wait for a key press
# cv2.destroyAllWindows()  # Close the window

# %% [markdown]
# ## 4. Using PIL (For Basic Image Handling)
# ```python
# from PIL import Image
#
# img = Image.open("image.jpg")  # Load the image
# img.show()  # Display the image

# %% [markdown]
# ## 5. In markdown
# ```markdown
# ![Alt text](<image.jpg>)
#
# If you want to resize the image (in platforms that support HTML), use:
#
# <img src="image.jpg" alt="Alt text" width="300">
#
# for online images
#
# ![Alt text](https://your-image-url.com/image.png)

# %% [markdown]
# ## 6. Using HTML (Recommended for Local Images) in VSCode jupyter notebook
# ```python
# <img src="C:/Users/Yahya/Desktop/My folder/Programming/Python/DataSciencePython/while loops.png" alt="While Loop" width="500">

# %%
try:
    hours_hiking = float(input("Enter the number of hours spent hiking: "))
    ounces_of_water = hours_hiking *24

    print(f"You should bring {ounces_of_water} ounces of water.")
except ValueError:
    print("Invalid input. Please enter a number.")
# Out:
# You should bring 144.0 ounces of water.
